# %%
import pandas as pd

# %%
# !wget -O  /home/cvd/projects/ml-ops/01-intro/data/green_tripdata_2021-01.parquet https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet
# !wget -O  /home/cvd/projects/ml-ops/01-intro/data/green_tripdata_2021-02.parquet https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet
# Out:
# --2023-06-03 22:13:39--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-01.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 52.85.6.129, 52.85.6.201, 52.85.6.219, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|52.85.6.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1333519 (1.3M) [binary/octet-stream]
# Saving to: ‘/home/cvd/projects/ml-ops/01-intro/data/green_tripdata_2021-01.parquet’
#
# /home/cvd/projects/ 100%[===================>]   1.27M  4.03MB/s    in 0.3s
#
# 2023-06-03 22:13:40 (4.03 MB/s) - ‘/home/cvd/projects/ml-ops/01-intro/data/green_tripdata_2021-01.parquet’ saved [1333519/1333519]
#
# --2023-06-03 22:13:40--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2021-02.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 52.85.6.129, 52.85.6.201, 52.85.6.219, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|52.85.6.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1145679 (1.1M) [binary/octet-stream]
# Saving to: ‘/home/cvd/projects/ml-ops/01-intro/data/green_tripdata_2021-02.parquet’
#
# /home/cvd/projects/ 100%[===================>]   1.09M  2.45MB/s    in 0.4s
#
# 2023-06-03 22:13:41 (2.45 MB/s) - ‘/home/cvd/projects/ml-ops/01-intro/data/green_tripdata_2021-02.parquet’ saved [1145679/1145679]

# %%
df = pd.read_parquet(r'./data/green_tripdata_2021-01.parquet')

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df = df[df.trip_type == 2]

# %%
df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds()/60)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 6             2  2021-01-01 00:19:14   2021-01-01 00:19:21                  N
# 15            2  2021-01-01 00:29:05   2021-01-01 00:29:07                  N
# 30            2  2021-01-01 00:35:29   2021-01-01 00:55:15                  N
# 43            2  2021-01-01 23:12:41   2021-01-02 01:13:53                  N
# 45            2  2021-01-01 01:49:29   2021-01-01 01:49:33                  N
# ...         ...                  ...                   ...                ...
# 40363         2  2021-01-31 19:26:20   2021-01-31 19:35:47                  N
# 40364         2  2021-01-31 19:44:54   2021-01-31 20:19:56                  N
# 40377         2  2021-01-31 20:09:41   2021-01-31 20:10:21                  N
# 40394         2  2021-01-31 20:38:42   2021-01-31 20:38:45                  N
# 40430         2  2021-01-31 21:48:08   2021-01-31 22:11:17                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 6             5.0           265           265              1.0           0.00
# 15            5.0            42           264              1.0           0.00
# 30            5.0            74           247              1.0           3.64
# 43            5.0            95            82              1.0           0.00
# 45            5.0           244           244              5.0           0.02
# ...           ...           ...           ...              ...            ...
# 40363         5.0           167           248              2.0           1.31
# 40364         5.0           147           147              2.0           6.97
# 40377         5.0            95            95              1.0           0.00
# 40394         5.0            75           264              1.0           0.00
# 40430         5.0            69           242              2.0           6.32
#
#        fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 6            180.0  ...      0.0       36.06           0.0       None
# 15            10.0  ...      0.0        2.06           0.0       None
# 30            13.0  ...      0.0        0.00           0.0       None
# 43             9.7  ...      0.0        2.00           0.0       None
# 45            12.0  ...      0.0        2.46           0.0       None
# ...            ...  ...      ...         ...           ...        ...
# 40363         10.0  ...      0.0        0.00           0.0       None
# 40364         30.0  ...      0.0        0.00           0.0       None
# 40377         15.0  ...      0.0        3.06           0.0       None
# 40394          5.0  ...      0.0        0.20           0.0       None
# 40430         16.0  ...      0.0        0.00           0.0       None
#
#       improvement_surcharge  total_amount  payment_type  trip_type  \
# 6                       0.3        216.36           1.0        2.0
# 15                      0.3         12.36           1.0        2.0
# 30                      0.3         13.30           2.0        2.0
# 43                      0.3         12.00           1.0        2.0
# 45                      0.3         14.76           1.0        2.0
# ...                     ...           ...           ...        ...
# 40363                   0.3         10.30           2.0        2.0
# 40364                   0.3         30.30           2.0        2.0
# 40377                   0.3         18.36           1.0        2.0
# 40394                   0.3          5.50           1.0        2.0
# 40430                   0.3         16.30           2.0        2.0
#
#        congestion_surcharge    duration
# 6                       0.0    0.116667
# 15                      0.0    0.033333
# 30                      0.0   19.766667
# 43                      0.0  121.200000
# 45                      0.0    0.066667
# ...                     ...         ...
# 40363                   0.0    9.450000
# 40364                   0.0   35.033333
# 40377                   0.0    0.666667
# 40394                   0.0    0.050000
# 40430                   0.0   23.150000
#
# [1238 rows x 21 columns]
